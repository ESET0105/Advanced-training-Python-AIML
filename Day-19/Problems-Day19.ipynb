# %% [markdown]
# Task1 - Regression Techniques
#
# 1. Load a dataset (e.g., Boston Housing or any housing dataset) and build a simple linear regression model to predict house prices based on one independent variable (e.g., square footage).
#
# 2. Plot the regression line and interpret the slope.
#
# 3. Use multiple linear regression on the same dataset to include additional features like number of rooms and age of the house.
#
# 4. Evaluate model performance using R² and RMSE.
#
# 5. Compare the performance of simple vs multiple regression models and explain which performs better and why.

# %%
# from sklearn.datasets import load_boston


# boston = load_boston()

# %% [markdown]
# Task 2 - Lasso & Ridge Regression
#
# 1.	Use the Boston Housing dataset (or any dataset with numerical predictors).
#
# 2.	Apply Lasso Regression and tune the regularization parameter α using cross-validation.
#
# 3.	Identify which features get reduced to zero.
#
# 4.	Apply Ridge Regression to the same dataset.
#
# 5.	Compare the coefficients with those from Lasso and Linear Regression.
#
# 6.	Discuss how Ridge helps in reducing overfitting.
#
# 7.	Plot the change in coefficients as α increases for both Lasso and Ridge Regression.

# %% [markdown]
# Task 3 - Classification Models
# 1. Use a dataset (like Titanic) to build a classification model that predicts a categorical target variable (e.g., survived/not survived).
#
# 2. Compare at least two classifiers (e.g., Logistic Regression vs Decision Tree).
#
# 3. Evaluate your model using a confusion matrix, accuracy, precision, recall, and F1-score.

# %%
# dataset = https://www.kaggle.com/datasets/yasserh/titanic-dataset?select=Titanic-Dataset.csv

# %% [markdown]
# Task 4 - Decision Tree
#
# 1. Build a decision tree classifier using the Iris dataset.
#
# 2. Visualize the decision tree and interpret the first two splits.
#
# 3. Use a decision tree regressor on a housing dataset to predict house prices. Tune the tree’s depth and analyze how it affects overfitting.

# %% [markdown]
# Task 5 - Clustering Models
#
# 1. Perform K-Means clustering on a customer segmentation dataset (e.g., Mall Customers).
#
# 2. Determine the optimal number of clusters using the Elbow method/Silhoutte Score.
#
# 3. Visualize the clusters and interpret them.
#
# 4. Apply Hierarchical clustering on the same dataset.
#
# 5. Plot the dendrogram and explain how to choose the number of clusters.
#
# 6. Compare results from K-Means and Hierarchical clustering. Which gives more interpretable clusters?

# %%
# link = https://raw.githubusercontent.com/tanishq21/Mall-Customers/refs/heads/main/Mall_Customers.csv

# %% [markdown]
# Task 6 - Visualization using Power BI
#
# 1. Import a dataset (like Sales or HR Analytics) into Power BI.
#
# 2. Create a dashboard showing total sales, region-wise distribution, and top 5 performing products.
#
# 3. Use Power BI slicers and filters to allow dynamic visualization (e.g., filter sales by year, category, or region).
#
# 4. Create a clustered bar chart, pie chart, and line graph in Power BI showing trends over time.
#
# Add insights or KPIs (e.g., growth % vs previous year).
